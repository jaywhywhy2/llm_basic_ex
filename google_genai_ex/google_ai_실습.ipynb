# %% [markdown]
# # Google Gemini 실습

# %% [markdown]
# ### 환경변수 로딩

# %%
from dotenv import load_dotenv
import os

# .env 파일 로드, # 기존 환경변수 덮어쓰기
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv('GEMINI_API_KEY')
print(OPENAI_API_KEY)
# Out:
# AIzaSyCaYbbltVr-A8Rszq-Ji0-igfmTJ2bmv9Q

# %% [markdown]
# ### 라이브러리 로딩 및 개체 생성

# %%
from google import genai 

#he client gets the API key from the environment variable GEMINI_API_KEY.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", 
    contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns from data to find patterns and make decisions or predictions.
